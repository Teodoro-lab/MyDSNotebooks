# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../input/supermarket-sales/supermarket_sales - Sheet1.csv')
df.head().T

# %% [markdown]
# ### Posibles insigths:
#
# 1. Momento del día en el que más compran determinado tipo de clientes ✔
# 2. ¿Qué compran más hombres y mujeres en determinadas fechas del año? 🕔
# 3. ¿Qué método de pago es más utilizado por los distintos tipos de cliente?
# 4. Información geográfica respecto a las ciudades, tipo de Branch vs linea de producto, precio y margen de ganancia
# 5. ¿Cuáles son los productos más caros?
#
# ---
#
# ### Observaciones preliminares del DF:
#
# - `gross income == tax 5%`
# - `Total == cost of goods sold(cogs) + (gross income or tax 5%)`
# - `gross margin percentage == 4.761905`

# %%
"""--------------------------------------------------------------------------
    1. Momento del día en el que más compran determinado tipo de clientes
   --------------------------------------------------------------------------
"""
df['Date/Time'] = pd.to_datetime(df['Date'] + ' ' + df['Time'])
del(df['Time'])
del(df['Date'])
df.head()

# %%
df['Hour'] = df['Date/Time'].dt.hour
df.head()

# %%
df[df['Customer type'] == 'Member']['Hour'].hist(alpha=.5)
df[df['Customer type'] == 'Normal']['Hour'].hist(alpha=.5)
plt.legend(['Member', 'Normal'])
plt.show()

# %%
"""--------------------------------------------------------------------------
    2. ¿Qué compran más hombres y mujeres en determinadas fechas del año? 
   --------------------------------------------------------------------------
"""
gender_vs_productLine_avg_sells = df.pivot_table('Total', index='Gender', columns='Product line')
gender_vs_productLine_avg_sells

# %%
# sns.catplot(x="Gender", y="Total", hue="Product line", kind="bar", data=df) -> No es muy clara la gráfica...
labels = gender_vs_productLine_avg_sells.columns
men_means = gender_vs_productLine_avg_sells.loc['Male']
women_means = gender_vs_productLine_avg_sells.loc['Female']

x = np.arange(len(labels))  # the label locations
width = 0.3  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()
fig.set_size_inches(18.5, 10.5)
# plt.xticks(rotation=45)
plt.show()

# %%
"""..."""

# %%
"""-----------------------------------------------------------------------------
    3. ¿Qué método de pago es más utilizado por los distintos tipos de cliente? 
   -----------------------------------------------------------------------------
"""
n_of_payment_type_by_customer_type = df.groupby(['Customer type'])['Payment'].value_counts()
sns.countplot(x='Customer type', hue='Payment', data=df)
plt.legend(loc='lower right')
plt.show()

# %%
# ?plt.legend

# %%
"""----------------------------------------------------------------------------------------------------------------------
    4. Información geográfica respecto a las ciudades, tipo de Branch vs linea de producto, precio y margen de ganancia
   ----------------------------------------------------------------------------------------------------------------------
"""

# %%
"""------------------------------------------
    5. ¿Cuáles son los productos más caros?
   ------------------------------------------
"""

# %%
"""--------------------------------
    6. Productos más comprados
   --------------------------------
"""
_ = sns.boxplot(x='Product line', y='Quantity', data=df)
_ =  plt.xticks(rotation=45)
